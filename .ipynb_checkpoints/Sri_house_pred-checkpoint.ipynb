# %% [markdown]
# # https://www.kaggle.com/lasaljaywardena/sri-lanka-house-prices-dataset

# %%
import pandas as pd
import seaborn as sns 
import numpy as np
import matplotlib.pyplot as plt

# %%
def reset():
    return pd.read_csv('./house_prices.csv')

# %%
data = pd.read_csv('./house_prices.csv')
data.head(2)
# Out:
#                                                Title  \
# 0        House with Land for Sale in Matara for sale
# 1  à¶
# à¶½à·à¶­à· à¶à·à¶¸à¶» 3 à¶ à¶à·à· à...
#
#                                          Sub_title          Price  \
# 0    Posted on 06 Nov 2:32 pm, Matara City, Matara   Rs 5,400,000
# 1  Posted on 24 Oct 7:27 am, Athurugiriya, Colombo  Rs 16,800,000
#
#                              Address Baths     Land size Beds    House size  \
# 0  Gangodagama Roard,Hakmana,Matara.     1  50.0 perches    3  1,600.0 sqft
# 1         Athurugiriya Galwarusapare     3   8.0 perches    3  1,480.0 sqft
#
#                   Location                                        Description  \
# 0     Matara City,  Matara  Land for sale with house Matara,Hakmana Gangod...
# 1   Athurugiriya,  Colombo  *House For Sale In Athurugiriya *Galwarusapare...
#
#                                             Post_URL           Seller_name  \
# 0  https://ikman.lk/en/ad/house-with-land-for-sal...        Ishara Dilshan
# 1  https://ikman.lk/en/ad/alut-kaamr-3-k-grh-bhaa...  DILRUWAN REAL ESTATE
#
#       Seller_type       published_date                       Geo_Address  \
# 0          Member  2021-11-06 14:32:00    Matara City, Matara, Sri Lanka
# 1  Premium-Member  2021-10-24 07:27:00  Athurugiriya, Colombo, Sri Lanka
#
#          Lat       Lon
# 0  80.500000  6.166670
# 1  79.989929  6.877246

# %%
data.shape
# Out:
# (15327, 17)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15327 entries, 0 to 15326
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Title           15327 non-null  object
#  1   Sub_title       15327 non-null  object
#  2   Price           15327 non-null  object
#  3   Address         11191 non-null  object
#  4   Baths           15327 non-null  object
#  5   Land size       15327 non-null  object
#  6   Beds            15327 non-null  object
#  7   House size      15327 non-null  object
#  8   Location        15327 non-null  object
#  9   Description     15327 non-null  object
#  10  Post_URL        15327 non-null  object
#  11  Seller_name     15327 non-null  object
#  12  Seller_type     15327 non-null  object
#  13  published_date  15327 non-null  object
#  14  Geo_Address     15327 non-null  object
#  15  Lat             15327 non-null  float64
#  16  Lon             15327 non-null  float64
# dtypes: float64(2), object(15)
# memory usage: 2.0+ MB

# %%
data.isnull().sum()
# Out:
# Title                0
# Sub_title            0
# Price                0
# Address           4136
# Baths                0
# Land size            0
# Beds                 0
# House size           0
# Location             0
# Description          0
# Post_URL             0
# Seller_name          0
# Seller_type          0
# published_date       0
# Geo_Address          0
# Lat                  0
# Lon                  0
# dtype: int64

# %%
data.Address.isna().sum()/ len(data)
# Out:
# 0.26985059046127746

# %%
data.head(2)
# Out:
#                                                Title  \
# 0        House with Land for Sale in Matara for sale
# 1  à¶
# à¶½à·à¶­à· à¶à·à¶¸à¶» 3 à¶ à¶à·à· à...
#
#                                          Sub_title          Price  \
# 0    Posted on 06 Nov 2:32 pm, Matara City, Matara   Rs 5,400,000
# 1  Posted on 24 Oct 7:27 am, Athurugiriya, Colombo  Rs 16,800,000
#
#                              Address Baths     Land size Beds    House size  \
# 0  Gangodagama Roard,Hakmana,Matara.     1  50.0 perches    3  1,600.0 sqft
# 1         Athurugiriya Galwarusapare     3   8.0 perches    3  1,480.0 sqft
#
#                   Location                                        Description  \
# 0     Matara City,  Matara  Land for sale with house Matara,Hakmana Gangod...
# 1   Athurugiriya,  Colombo  *House For Sale In Athurugiriya *Galwarusapare...
#
#                                             Post_URL           Seller_name  \
# 0  https://ikman.lk/en/ad/house-with-land-for-sal...        Ishara Dilshan
# 1  https://ikman.lk/en/ad/alut-kaamr-3-k-grh-bhaa...  DILRUWAN REAL ESTATE
#
#       Seller_type       published_date                       Geo_Address  \
# 0          Member  2021-11-06 14:32:00    Matara City, Matara, Sri Lanka
# 1  Premium-Member  2021-10-24 07:27:00  Athurugiriya, Colombo, Sri Lanka
#
#          Lat       Lon
# 0  80.500000  6.166670
# 1  79.989929  6.877246

# %%
data = reset()
def format_data(data):
    data['Price'] = data['Price'].apply(lambda x: x.split('Rs')[1].strip())
    data['Price'] = data['Price'].apply(lambda x: x.replace(',',''))
    data['House size'] = data['House size'].apply(lambda x : x.split('sqft')[0].strip())
    data['House size'] = data['House size'].apply(lambda x : x.replace(',',''))
    data['Land size'] = data['Land size'].apply(lambda x : x.split('perches')[0].strip())
    data['Price']=data['Price'].astype(float)
    data['House size']=data['House size'].astype(float)
    data['Hour'] = pd.to_datetime(data['published_date']).dt.hour
    data['Minute'] = pd.to_datetime(data['published_date']).dt.minute
    data['Seconds']= pd.to_datetime(data['published_date']).dt.second
    data['Day']= pd.to_datetime(data['published_date']).dt.day
    data['Month']= pd.to_datetime(data['published_date']).dt.month
    data['Year']= pd.to_datetime(data['published_date']).dt.year
    temp = pd.DataFrame()
    temp['Seller_type'] = data['Seller_type']
    temp['Location'] = data['Location']
    temp['is_Premium-Member'] = np.where(temp['Seller_type'] == 'Premium-Member',1,0)
    temp['Location']
    temp['District'] = temp['Location'].apply(lambda x: x.split(',')[1].strip())
    temp['City'] = temp['Location'].apply(lambda x: x.split(',')[0].strip())
    temp = temp.drop(['Seller_type','Location'],1)
    temp = pd.get_dummies(temp)
    data = data.join(temp)
    data = data.drop(['Title','Sub_title','Address','Post_URL','Seller_name','Seller_type','Location','Description','Geo_Address','published_date'],1)

# %%
data['Price'] = data['Price'].apply(lambda x: x.split('Rs')[1].strip())
data['Price'] = data['Price'].apply(lambda x: x.replace(',',''))
data['House size'] = data['House size'].apply(lambda x : x.split('sqft')[0].strip())
data['House size'] = data['House size'].apply(lambda x : x.replace(',',''))
data['Land size'] = data['Land size'].apply(lambda x : x.split('perches')[0].strip())
data['Price']=data['Price'].astype(float)
data['House size']=data['House size'].astype(float)
data['Hour'] = pd.to_datetime(data['published_date']).dt.hour
data['Minute'] = pd.to_datetime(data['published_date']).dt.minute
data['Seconds']= pd.to_datetime(data['published_date']).dt.second
data['Day']= pd.to_datetime(data['published_date']).dt.day
data['Month']= pd.to_datetime(data['published_date']).dt.month
data['Year']= pd.to_datetime(data['published_date']).dt.year

# %%
temp = pd.DataFrame()
temp['Seller_type'] = data['Seller_type']
temp['Location'] = data['Location']
temp['is_Premium-Member'] = np.where(temp['Seller_type'] == 'Premium-Member',1,0)
temp['Location']
temp['District'] = temp['Location'].apply(lambda x: x.split(',')[1].strip())
temp['City'] = temp['Location'].apply(lambda x: x.split(',')[0].strip())
temp = temp.drop(['Seller_type','Location'],1)
temp = pd.get_dummies(temp)

# %%
data = data.join(temp)

# %%
data = data.drop(['Title','Sub_title','Address','Post_URL','Seller_name','Seller_type','Location','Description','Geo_Address','published_date'],1)

# %%
data.columns
# Out:
# Index(['Price', 'Baths', 'Land size', 'Beds', 'House size', 'Lat', 'Lon',
#        'Hour', 'Minute', 'Seconds',
#        ...
#        'City_Warakapola', 'City_Wariyapola', 'City_Wattala', 'City_Wattegama',
#        'City_Weligama', 'City_Welimada', 'City_Wellampitiya', 'City_Wellawaya',
#        'City_Wennappuwa', 'City_Yatiyantota'],
#       dtype='object', length=210)

# %%
for c in ['Price', 'Baths', 'Land size', 'Beds', 'House size', 'Lat', 'Lon',]:
    plt.figure(figsize=(16,8))
    f, (ax1, ax2) = plt.subplots(1, 2)
    ax1.hist(x=data[c])
    ax1.set_title(c)
    ax2.boxplot(x=data[c])
    ax2.set_title(c)
    plt.show()
    print(data[c].describe())
# Out:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: Price, dtype: float64
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: Baths, dtype: float64
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: Land size, dtype: float64
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: Beds, dtype: float64
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: House size, dtype: float64
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: Lat, dtype: float64
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: Lon, dtype: float64

# %%
Q1 = data.quantile(0.25)
Q3 = data.quantile(0.75)
IQR = Q3 - Q1

data = data[~((data < (Q1 - 1.5 * IQR)) |(data > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
data
# Out:
# Empty DataFrame
# Columns: [Price, Baths, Land size, Beds, House size, Lat, Lon, Hour, Minute, Seconds, Day, Month, Year, is_Premium-Member, District_Ampara, District_Anuradhapura, District_Badulla, District_Batticaloa, District_Colombo, District_Galle, District_Gampaha, District_Hambantota, District_Jaffna, District_Kalutara, District_Kandy, District_Kegalle, District_Kurunegala, District_Mannar, District_Matale, District_Matara, District_Monaragala, District_Mullativu, District_Nuwara Eliya, District_Polonnaruwa, District_Puttalam, District_Ratnapura, District_Trincomalee, District_Vavuniya, City_Ahangama, City_Akkarepattu, City_Akuressa, City_Alawwa, City_Alutgama, City_Ambalangoda, City_Ambalantota, City_Ampara City, City_Ampitiya, City_Angoda, City_Anuradhapura City, City_Athurugiriya, City_Avissawella, City_Baddegama, City_Badulla City, City_Balangoda, City_Bandaragama, City_Bandarawela, City_Batapola, City_Battaramulla, City_Batticaloa City, City_Beliatta, City_Beruwala, City_Bibile, City_Boralesgamuwa, City_Buttala, City_Chilaw, City_Colombo 1, City_Colombo 10, City_Colombo 12, City_Colombo 13, City_Colombo 14, City_Colombo 15, City_Colombo 2, City_Colombo 3, City_Colombo 4, City_Colombo 5, City_Colombo 6, City_Colombo 7, City_Colombo 8, City_Colombo 9, City_Dambulla, City_Dankotuwa, City_Dehiowita, City_Dehiwala, City_Delgoda, City_Deniyaya, City_Digana, City_Dikwella, City_Divulapitiya, City_Eheliyagoda, City_Ella, City_Elpitiya, City_Embilipitiya, City_Eppawala, City_Galewela, City_Galgamuwa, City_Galigamuwa, City_Galle City, City_Galnewa, City_Gampaha City, City_Gampola, ...]
# Index: []
#
# [0 rows x 210 columns]

# %%
from sklearn.preprocessing import LabelEncoder
for column in data.columns:
    if data[column].dtype == np.number
        continue
    data[column] = LabelEncoder().fit_transform(data[column])
# Out:
# <ipython-input-314-8f3c119c5840>:3: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if data[column].dtype == np.number:

# %%
for i in data.columns:
    pass# print(i,data[i].nunique(),data[i].dtype)

# %%
for c in data.columns:
    if data[c].isnull().sum() > 0:
        print(c,data[c].isnull().sum())

# %%
plt.figure(figsize=(16,8))
sns.heatmap(data.corr())
plt.show()

# %%
X = data.drop('Price',1)
y = data['Price']

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler
X = MinMaxScaler().fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_squared_log_error


from sklearn.svm import SVC

# %%
train_x,test_x,train_y,test_y = train_test_split(X,y,random_state=26,test_size=.25)

# %%
model = SVC()
model.fit(train_x,train_y)
# Out:
# SVC()

# %%
pred = model.predict(test_x)

# %%
model.score(test_x, test_y)
# Out:
# 0.1714509394572025

# %%
print("MAE:",mean_absolute_error(test_y,pred))
print("MSE:",mean_squared_error(test_y,pred))
print("MSLE:",mean_squared_log_error(test_y,pred))
# Out:
# MAE: 13478474.222599166
# MSE: 1302113211275150.8
# MSLE: 0.316592291245287

# %%
temp = pd.DataFrame()
temp['price'] = test_y
temp['pred'] = pred

# %%
temp
# Out:
#             price        pred
# 2967   69000000.0  27000000.0
# 10440  12000000.0   7500000.0
# 6564    7500000.0   8500000.0
# 11083  27000000.0  25500000.0
# 3514   48000000.0  28000000.0
# ...           ...         ...
# 7661   12000000.0  12500000.0
# 13221  24800000.0  25500000.0
# 14377  28000000.0  36000000.0
# 7229   26000000.0  45000000.0
# 4675   21500000.0   6500000.0
#
# [3832 rows x 2 columns]

# %%
plt.figure(figsize=(16,8))
sns.scatterplot(temp.index,temp['price'])
sns.scatterplot(temp.index,temp['pred'])
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
